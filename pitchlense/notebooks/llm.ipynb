# %%
# load_env
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys, os
sys.path.append("../..")

# %%
from pitchlense.llm.google_gemini import GeminiTextGenerator, GeminiImageAnalyzer, GeminiVideoAnalyzer, GeminiAudioAnalyzer, GeminiDocumentAnalyzer

# %%
llm = GeminiTextGenerator()
llm.predict(system_message="You are a helpful assistant.", user_message="Hello, how are you?")
# Out:
# {'response': "Hello! I'm doing well, thank you for asking. How are you today?",
#  'usage': {'model': 'gemini-2.5-flash', 'type': 'text_generation'}}

# %%
llm = GeminiImageAnalyzer()
llm.predict(image_input=r"C:\Users\conne\Downloads\download.png", prompt="Describe the image.")
# Out:
# {'text': 'This image displays a clear, digitally presented academic document, specifically a "MARKS STATEMENT CUM CERTIFICATE" for the "SENIOR SCHOOL CERTIFICATE EXAMINATION, 2021" from the "CENTRAL BOARD OF SECONDARY EDUCATION" (CBSE). The document is bordered by a thin green line.\n\nHere\'s a detailed description:\n\n1.  **Header and Branding:**\n    *   At the top center, the logo of the "CENTRAL BOARD OF SECONDARY EDUCATION" is prominently displayed, featuring an open book and lamp motif within a circular emblem, surrounded by text in both Hindi ("केन्द्रीय माध्यमिक शिक्षा बोर्ड") and English.\n    *   Below the logo, the document\'s main title is given in Hindi and English, identifying it as a marks statement and certificate for the Senior School Certificate Examination, 2021.\n\n2.  **Student and Personal Information:**\n    *   The document certifies that "ANKIT JHA" (name of the student) passed the examination.\n    *   Further details include the student\'s Roll No. (146009
# ...

# %%
llm = GeminiVideoAnalyzer()
llm.predict(video_input=r"C:\Users\conne\Videos\2025-07-27 16-03-52.mkv", prompt="Transcribe the video.")
# Out:
# {'text': 'हा यह प्रॉम्प्ट डाल WhatsApp प्रॉम्प्ट है ठीक है यह व्हाट्सएप पर भेज दूंगा तो यह प्रॉम्प्ट में वाइफइ मार्केट ऑफ इंडिया एंड दिन वेअर आस्किंग सम डीटेल्स अबाउट दी ग्राफ एंड इट हैज़ जनरेटेड द कोड इन HTML CSS Javascript दिस इज द स्लाइड विद लेफ्ट हैंड साइड शोइंग मार्केट ग्रोथ इन कंपोजीशनस दैट इज़ हार्डवेयर सॉफ्टवेयर एंड अ सर्विसेज एंड राइट हैंड साइड द डिस्क्रिप्शन सॉरी डिस्रप्सनस के अगर मिस कर दिया ना इसने हां के अगर नहीं डाला शायद उसके पास वह नॉलेज नहीं होगा ना के अगर नहीं नहीं सब नॉलेज है वो उसको स्टैक्ड बार चार्ट बनाने का और परसेंटेज',
#  'model': 'gemini-2.5-flash',
#  'prompt': 'Transcribe the video.',
#  'mime_type': 'video/mp4',
#  'input_type': 'path',
#  'file_size_mb': 4.414684295654297}

# %%
llm = GeminiAudioAnalyzer()
llm.predict(audio_input=r"C:\Users\conne\Downloads\clapping-at-a-conference-81031.mp3", prompt="Describe/Transcribe the audio.")
# Out:
# {'text': 'The audio features **applause**. It sounds like an audience clapping enthusiastically.',
#  'model': 'gemini-2.5-flash',
#  'prompt': 'Describe/Transcribe the audio.',
#  'mime_type': 'audio/mp3',
#  'input_type': 'path',
#  'file_size_mb': 0.18768310546875}

# %%
llm = GeminiDocumentAnalyzer()
llm.predict(document_path=r"C:\Users\conne\Downloads\1.pdf", prompt="You are a OCR assistant. Extract the text from the document.")
# Out:
# {'text': 'AI in Modern Education\nThis is a randomly generated paragraph for demo purposes.\nRandom Shape + Table (demo only)',
#  'model': 'gemini-2.5-flash',
#  'document_path': 'C:\\Users\\conne\\Downloads\\1.pdf',
#  'prompt': 'You are a OCR assistant. Extract the text from the document.',
#  'mime_type': 'application/pdf'}
